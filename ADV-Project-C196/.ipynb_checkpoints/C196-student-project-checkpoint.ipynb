# %%
print("Name : Lakshya Singh Chauhan")
print("Clean the data and show which top 10 countries has the highest Undernourished rate as compared with their Population")
print("Show a comparison between Meat and Vegetables consumption across the countries")
# Out:
# Name : Lakshya Singh Chauhan
# Clean the data and show which top 10 countries has the highest Undernourished rate as compared with their Population
# Show a comparison between Meat and Vegetables consumption across the countries

# %%
#predefine code for image
from IPython.display import Image
Image(filename='healthy.jpg') 
#predefine code end

# %% [markdown]
# # Activity - 1 Clean the data and show which top 10 countries has the highest Undernourished rate as compared with their Population

# %%
#import the required packages 
import pandas as pd
import matplotlib.pyplot as plt

#Read the csv file.
df = pd.read_csv("COVID-19 Healthy Diet Dataset.csv")
new_df = df.dropna()
df
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 0         0.0277                   0.0000                   35.9771  0.4067
# 1         0.0711                   0.0000                   14.2331  1.8069
# 2         0.0054                   0.0000                   26.5633  1.2916
# 3         0.0277                   0.0000                   20.3882  0.1756
# 4         0.1289                   0.0000                   10.5108  0.4850
# ..           ...                      ...                       ...     ...
# 165       0.1244                   0.0000                   21.6526  0.8707
# 166       0.1555                   0.0056                   18.5247  0.7665
# 167       0.0188                   0.0000                   35.1179  0.4320
# 168       0.0338                   0.0000                   28.5182  0.5839
# 169       0.0391                   0.0000                   33.1934  0.5077
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetables  \
# 0           0.0647                   0.5824   3.1337  ...      1.1370
# 1           0.6274                   1.2757   7.6582  ...      3.2456
# 2           0.6350                   1.1624   3.5088  ...      3.1267
# 3           5.4436                   1.2754   7.6248  ...      0.8133
# 4           8.2146                   1.2586  16.0670  ...      1.6024
# ..             ...                      ...      ...  ...         ...
# 165         2.6477                   1.0662  11.8347  ...      1.0129
# 166         5.7435                   0.7165  11.0426  ...      3.7216
# 167         0.9392                   0.4884   5.9453  ...      0.5448
# 168         3.0126                   0.0931   4.3158  ...      0.8039
# 169         1.0837                   0.2636   6.6582  ...      0.5955
#
#      Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0           0.0462      4.5            29.8   0.138283  0.005970   0.116713
# 1           0.0544     22.3             6.2   2.347956  0.044574   1.396230
# 2           0.1399     26.6             3.9   0.233066  0.006373   0.158234
# 3           0.0924      6.8            25.0   0.057435  0.001316   0.049566
# 4           0.2947     19.1             NaN   0.187755  0.006122   0.159184
# ..             ...      ...             ...        ...       ...        ...
# 165         0.0267     25.2            21.2   0.414928  0.003823   0.392110
# 166         0.0389      2.1             9.3   0.001597  0.000036   0.001434
# 167         0.0564     14.1            38.9   0.007078  0.002052   0.004758
# 168         0.0592      6.5            46.7   0.186456  0.002867   0.131119
# 169         0.0586     12.3            51.3   0.175664  0.004481   0.103707
#
#        Active  Population  Unit (all except Population)
# 0    0.015601  38928000.0                             %
# 1    0.907153   2838000.0                             %
# 2    0.068458  44357000.0                             %
# 3    0.006552  32522000.0                             %
# 4    0.022449     98000.0                             %
# ..        ...         ...                           ...
# 165  0.018995  28645000.0                             %
# 166  0.000126  96209000.0                             %
# 167  0.000268  29826000.0                             %
# 168  0.052470  18384000.0                             %
# 169  0.067476  14863000.0                             %
#
# [170 rows x 32 columns]

# %%
#Cleaning data
new_df['Undernourished'].astype(float)
clean_data = new_df["Undernourished"]
clean_data.replace("<2.5", int(3), inplace=True)
new_df.dropna()
clean_data
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_14300\1003417287.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data.replace("<2.5", int(3), inplace=True)
# 0      29.8
# 1       6.2
# 2       3.9
# 3      25.0
# 5       4.6
#        ...
# 165    21.2
# 166     9.3
# 167    38.9
# 168    46.7
# 169    51.3
# Name: Undernourished, Length: 154, dtype: float64

# %%
#Converting object datatype column to float datatype
df['Undernourished'].astype(float)
df
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 0         0.0277                   0.0000                   35.9771  0.4067
# 1         0.0711                   0.0000                   14.2331  1.8069
# 2         0.0054                   0.0000                   26.5633  1.2916
# 3         0.0277                   0.0000                   20.3882  0.1756
# 4         0.1289                   0.0000                   10.5108  0.4850
# ..           ...                      ...                       ...     ...
# 165       0.1244                   0.0000                   21.6526  0.8707
# 166       0.1555                   0.0056                   18.5247  0.7665
# 167       0.0188                   0.0000                   35.1179  0.4320
# 168       0.0338                   0.0000                   28.5182  0.5839
# 169       0.0391                   0.0000                   33.1934  0.5077
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetables  \
# 0           0.0647                   0.5824   3.1337  ...      1.1370
# 1           0.6274                   1.2757   7.6582  ...      3.2456
# 2           0.6350                   1.1624   3.5088  ...      3.1267
# 3           5.4436                   1.2754   7.6248  ...      0.8133
# 4           8.2146                   1.2586  16.0670  ...      1.6024
# ..             ...                      ...      ...  ...         ...
# 165         2.6477                   1.0662  11.8347  ...      1.0129
# 166         5.7435                   0.7165  11.0426  ...      3.7216
# 167         0.9392                   0.4884   5.9453  ...      0.5448
# 168         3.0126                   0.0931   4.3158  ...      0.8039
# 169         1.0837                   0.2636   6.6582  ...      0.5955
#
#      Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0           0.0462      4.5            29.8   0.138283  0.005970   0.116713
# 1           0.0544     22.3             6.2   2.347956  0.044574   1.396230
# 2           0.1399     26.6             3.9   0.233066  0.006373   0.158234
# 3           0.0924      6.8            25.0   0.057435  0.001316   0.049566
# 4           0.2947     19.1             NaN   0.187755  0.006122   0.159184
# ..             ...      ...             ...        ...       ...        ...
# 165         0.0267     25.2            21.2   0.414928  0.003823   0.392110
# 166         0.0389      2.1             9.3   0.001597  0.000036   0.001434
# 167         0.0564     14.1            38.9   0.007078  0.002052   0.004758
# 168         0.0592      6.5            46.7   0.186456  0.002867   0.131119
# 169         0.0586     12.3            51.3   0.175664  0.004481   0.103707
#
#        Active  Population  Unit (all except Population)
# 0    0.015601  38928000.0                             %
# 1    0.907153   2838000.0                             %
# 2    0.068458  44357000.0                             %
# 3    0.006552  32522000.0                             %
# 4    0.022449     98000.0                             %
# ..        ...         ...                           ...
# 165  0.018995  28645000.0                             %
# 166  0.000126  96209000.0                             %
# 167  0.000268  29826000.0                             %
# 168  0.052470  18384000.0                             %
# 169  0.067476  14863000.0                             %
#
# [170 rows x 32 columns]

# %%
#Groupby country and apply sum on Undernourished and Population column and create a new dataframe out of it
group_country = df.groupby(["Undernourished", "Population"])["Country"].sum().reset_index()
group_country
# Out:
#      Undernourished  Population                   Country
# 0               2.5  32781000.0                  Malaysia
# 1               2.6   9778000.0      United Arab Emirates
# 2               2.7    125000.0                  Kiribati
# 3               2.7    200000.0                     Samoa
# 4               2.7  19470000.0                     Chile
# ..              ...         ...                       ...
# 158            46.7  18384000.0                    Zambia
# 159            47.8  25779000.0              Korea, North
# 160            49.3  11403000.0                     Haiti
# 161            51.3  14863000.0                  Zimbabwe
# 162            59.6   4830000.0  Central African Republic
#
# [163 rows x 3 columns]

# %%
#Sort the new dataframe as per Undernourished column
sort1 = group_country.sort_values(by="Undernourished", ascending=False)
sort1
# Out:
#      Undernourished  Population                   Country
# 162            59.6   4830000.0  Central African Republic
# 161            51.3  14863000.0                  Zimbabwe
# 160            49.3  11403000.0                     Haiti
# 159            47.8  25779000.0              Korea, North
# 158            46.7  18384000.0                    Zambia
# ..              ...         ...                       ...
# 4               2.7  19470000.0                     Chile
# 2               2.7    125000.0                  Kiribati
# 3               2.7    200000.0                     Samoa
# 1               2.6   9778000.0      United Arab Emirates
# 0               2.5  32781000.0                  Malaysia
#
# [163 rows x 3 columns]

# %%
#Get the top 10 countries from the sorted data
top_10 = sort1.head(10)
top_10
#Convert Undernourished percentage to number and add a new column to the top 10 countries dataframe
top_10["percentage_number"] = top_10["Undernourished"]/100 * top_10["Population"]
top_10
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_14300\1366676030.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10["percentage_number"] = top_10["Undernourished"]/100 * top_10["Population"]
#      Undernourished  Population                   Country  percentage_number
# 162            59.6   4830000.0  Central African Republic          2878680.0
# 161            51.3  14863000.0                  Zimbabwe          7624719.0
# 160            49.3  11403000.0                     Haiti          5621679.0
# 159            47.8  25779000.0              Korea, North         12322362.0
# 158            46.7  18384000.0                    Zambia          8585328.0
# 157            44.4  27691000.0                Madagascar         12294804.0
# 156            41.0  45741000.0                    Uganda         18753810.0
# 155            40.3   5518000.0                     Congo          2223754.0
# 154            38.9  29826000.0                     Yemen         11602314.0
# 153            37.5  16877000.0                      Chad          6328875.0

# %%
#Plot a stacked bar graph for showing the Population vs Undernourished rate
# Plot the data
ax = df.plot(kind='bar', x='Country', stacked=True)

# Add some labels and legends
ax.set_ylabel('Population / Undernourished')
ax.set_title('Population vs Undernourished Rate by Country')

# Display the plot
plt.show()

# %% [markdown]
# Conclusion -

# %% [markdown]
# # Activity - 2 Show a comparison between Meat and Vegetables consumption across the countries

# %%
#Sort the big dataframe as per Meat consumption
sorted_df = df.sort_values(by='Meat', ascending=False)
sorted_df
# Out:
#                    Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 5                Argentina               0.1704          31.9799       0.0097
# 10                 Bahamas               0.0325          34.1684       0.0895
# 101               Mongolia               0.2367          34.0697       0.1092
# 128  Saint Kitts and Nevis               0.3183          32.0169       0.1104
# 131                  Samoa               0.1866          30.9096       0.1341
# ..                     ...                  ...              ...          ...
# 142              Sri Lanka               0.0699          14.5498       0.0000
# 54                  Gambia               0.2116          13.0026       0.0078
# 48                Ethiopia               0.1676           4.4561       0.0076
# 11              Bangladesh               0.0000           9.9195       0.0083
# 68                   India               0.0077          11.2582       0.0306
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 5                     0.0000                   13.6702  2.0593         1.0223
# 10                    0.0000                    7.8081  1.6755         5.7340
# 101                   0.0000                   13.0902  0.7768         0.1032
# 128                   0.0000                   10.9516  0.7795         5.1770
# 131                   0.1341                    8.4665  0.4023         7.3761
# ..                       ...                       ...     ...            ...
# 142                   0.0000                   23.7396  1.0176         7.4963
# 54                    0.0000                   26.6870  0.3213         6.7403
# 48                    0.0000                   29.7303  0.0990         0.1066
# 11                    0.0000                   31.7243  0.7216         5.8306
# 68                    0.0000                   25.2794  0.7271         1.5537
#
#      Fruits - Excluding Wine     Meat  ...  Vegetables  Miscellaneous  \
# 5                     0.5209  21.6250  ...      1.0516         0.0000
# 10                    1.8788  20.4311  ...      2.6759         1.1305
# 101                   0.0850  19.8082  ...      0.8618         0.1699
# 128                   0.8444  19.6622  ...      0.8574         0.5781
# 131                   1.6968  19.3878  ...      0.5364         0.3032
# ..                       ...      ...  ...         ...            ...
# 142                   0.5438   2.4314  ...      1.5148         0.0388
# 54                    0.0705   2.3513  ...      0.6427         0.2116
# 48                    0.1143   1.6834  ...      0.4570         0.0076
# 11                    0.3069   1.2773  ...      1.2026         0.0249
# 68                    0.6659   1.0179  ...      2.3343         0.0000
#
#      Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 5       28.5             4.6   3.929407  0.099669   3.442191  0.387547
# 10      32.1             NaN   2.040967  0.044529   1.655725  0.340712
# 101     19.6            13.4   0.044987  0.000060   0.027046  0.017882
# 128     23.1             NaN   0.062963  0.000000   0.059259  0.003704
# 131     45.5             2.7   0.001000  0.000000   0.001000  0.000000
# ..       ...             ...        ...       ...        ...       ...
# 142      5.4             9.0   0.235192  0.001162   0.201755  0.032274
# 54       8.7            10.2   0.161233  0.005254   0.152627  0.003351
# 48       3.6            20.6   0.113410  0.001760   0.100446  0.011204
# 11       3.4            14.7   0.310045  0.004630   0.277443  0.027973
# 68       3.8            14.5   0.753006  0.010863   0.727071  0.015073
#
#        Population  Unit (all except Population)
# 5    4.537700e+07                             %
# 10   3.930000e+05                             %
# 101  3.361000e+06                             %
# 128  5.400000e+04                             %
# 131  2.000000e+05                             %
# ..            ...                           ...
# 142  2.193700e+07                             %
# 54   2.417000e+06                             %
# 48   1.149160e+08                             %
# 11   1.698090e+08                             %
# 68   1.400100e+09                             %
#
# [170 rows x 32 columns]

# %%
#Sort the big dataframe as per Vegetables consumption
sorted_df = df.sort_values(by='Vegetables', ascending=False)
sorted_df
# Out:
#                               Country  Alcoholic Beverages  Animal Products  \
# 148                        Tajikistan               0.0090          12.1401
# 6                             Armenia               0.0411          22.8846
# 81                       Korea, North               0.0287          10.0832
# 63                             Guyana               0.1537          22.1489
# 85   Lao People's Democratic Republic               0.0541          12.0786
# ..                                ...                  ...              ...
# 131                             Samoa               0.1866          30.9096
# 139                   Solomon Islands               0.1398          14.7782
# 48                           Ethiopia               0.1676           4.4561
# 22                       Burkina Faso               1.3660           7.1846
# 28                               Chad               0.0567          15.4353
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 148       0.0000                   0.0000                   28.2246  0.6499
# 6         0.1438                   0.0000                   18.2738  1.7560
# 81        0.0000                   0.0000                   23.9070  1.3872
# 63        0.0114                   0.0000                   15.7922  0.2902
# 85        0.1082                   0.0000                   25.5153  0.3365
# ..           ...                      ...                       ...     ...
# 131       0.1341                   0.1341                    8.4665  0.4023
# 139       0.0839                   0.0186                   15.0205  0.3168
# 48        0.0076                   0.0000                   29.7303  0.0990
# 22        0.0066                   0.0000                   29.1784  0.4466
# 28        0.0425                   0.0000                   22.6744  0.0709
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetables  \
# 148         0.0903                   0.5777   5.5601  ...      5.0546
# 6           0.8831                   1.1142   8.5233  ...      4.6621
# 81          2.9561                   0.6218   5.0990  ...      4.6398
# 63          4.6153                   0.8821   8.5306  ...      4.4560
# 85          4.5310                   1.9710   5.9912  ...      4.4408
# ..             ...                      ...      ...  ...         ...
# 131         7.3761                   1.6968  19.3878  ...      0.5364
# 139         9.1129                   0.5498   3.9415  ...      0.4752
# 48          0.1066                   0.1143   1.6834  ...      0.4570
# 22          1.4842                   0.0591   2.9750  ...      0.3809
# 28          2.2689                   0.0993   7.4872  ...      0.1631
#
#      Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 148         0.1083     12.6             NaN   0.141139  0.000955   0.140185
# 6           0.1078     20.9             4.3   5.547091  0.100609   5.152909
# 81          0.0287      7.1            47.8        NaN       NaN        NaN
# 63          0.2219     19.2             8.1   0.864676  0.021601   0.772935
# 85          0.1622      4.5            16.5   0.000566  0.000000   0.000566
# ..             ...      ...             ...        ...       ...        ...
# 131         0.3032     45.5             2.7   0.001000  0.000000   0.001000
# 139         0.2329     20.5             8.9   0.002378  0.000000   0.001399
# 48          0.0076      3.6            20.6   0.113410  0.001760   0.100446
# 22          0.0394      4.5            20.0   0.042492  0.000464   0.033617
# 28          0.0142      4.8            37.5   0.016632  0.000658   0.012324
#
#        Active   Population  Unit (all except Population)
# 148  0.000000    9429000.0                             %
# 6    0.293572    2956000.0                             %
# 81        NaN   25779000.0                             %
# 63   0.070140     787000.0                             %
# 85   0.000000    7242000.0                             %
# ..        ...          ...                           ...
# 131  0.000000     200000.0                             %
# 139  0.000979     715000.0                             %
# 48   0.011204  114916000.0                             %
# 22   0.008410   20903000.0                             %
# 28   0.003650   16877000.0                             %
#
# [170 rows x 32 columns]

# %%
#Plot a histogram showing the Meat consumption vs Vegetables consumption across countries 

# create a figure and axis object
fig, ax = plt.subplots()

# create two histograms on the same axis
ax.hist(df["Meat"], bins=10, alpha=0.5, label="Meat Consumption")
ax.hist(df["Vegetables"], bins=10, alpha=0.5, label="Vegetables Consumption")

# add axis labels and a legend
ax.set_xlabel("Consumption")
ax.set_ylabel("Count")
ax.legend()

# show the plot
plt.show()

# %% [markdown]
# Conclusion -
