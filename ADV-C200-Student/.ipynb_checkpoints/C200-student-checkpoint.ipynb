# %%
print('Name : Lakshya Singh Chauhan')
print('Create a GUI to read any CSV, clean the data, and create widgets to select the column names, and graph type')
# Out:
# Name : Lakshya Singh Chauhan
# Create a GUI to read any CSV, clean the data, and create widgets to select the column names, and graph type

# %%
#pre defined code
from ipywidgets import widgets
from IPython.display import display, clear_output
import pandas as pd
from tkinter import Tk, filedialog
import matplotlib.pyplot as plt 

graph_type = ['Choose one.. ','line','bar']
operation =['choose','mean','max','min','sum','count']
df = ''
new_df = ''


def select_files(b):
    clear_output()
    global df
    root = Tk()
    root.withdraw() 
    file_name = filedialog.askopenfilename()
    df = pd.read_csv(file_name)
    print(file_name)
#pre defined code end
    #complete select_files function
    df.replace("", float("nan"), inplace=True)
    df.replace("0", float("nan"), inplace=True)
    df.dropna()
    display(df)
    groupby_cols_widget = widgets.Dropdown(options=df.columns)
    operation_cols_widget = widgets.Dropdown(options=df.columns)
    operation_widget = widgets.Dropdown(options=operation)
    groupby_int = widgets.interactive(groupby_dataframe, groupby_columns=groupby_cols_widget,
                                     operation_column=operation_cols_widget, 
                                      operation=operation_widget)
    display(groupby_int)
    #End of select_files function

    
#Code for get_widget function
def get_widget():
    global df
    global new_df
    xlabel_dd = widgets.Dropdown(options=new_df.columns)
    ylabel_dd = widgets.Dropdown(options=new_df.columns)
    graph_widget = widgets.Dropdown(options=new_df.columns)
    graph = widgets.interactive(display_plot, xaxis=xlabel_dd, yaxis=ylabel_dd, graph_type=graph_widget)
    display(graph)

#Code for groupby_dataframe function
def groupby_dataframe(groupby_columns, operation_column, operation):
    print("Group by")

    
#pre defined code
fileselect = widgets.Button(description="File select")
fileselect.on_click(select_files)

display(fileselect)
#pre defined code end
# Out:
# D:/New coding folder/Python projects/ADV-C200-Student/heart_failure_clinical_records_dataset.csv
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# ...

# %%
import ipywidgets as widgets

# Define a function that takes a parameter and returns its square
def square(x):
    return x ** 2

# Create an interactive slider widget with a range from 0 to 10
# and a step size of 1, and connect it to the 'square' function
widgets.interactive(square, x=widgets.IntSlider(min=0, max=10, step=1))
# Out:
# interactive(children=(IntSlider(value=0, description='x', max=10), Output()), _dom_classes=('widget-interact',…
